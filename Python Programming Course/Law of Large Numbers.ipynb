# %%
import numpy as np
from numpy.random import randn

# %%
count = 0
for i in randn(100):
   
    if i >= -1 and i<=1:
        count += 1
percent = (count/100)*100
print(percent)
# Out:
# 68.0

# %% [markdown]
# ![image.png](attachment:image.png)
